# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([3,4])
a
# Out:
# array([3, 4])

# %%
print(a)
# Out:
# [3 4]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
len(a)
# Out:
# 2

# %%
a[0] , a[1]
# Out:
# (np.int64(3), np.int64(4))

# %%
b = np.array([7,2])
print(b)
# Out:
# [7 2]

# %%
print(a,b)
# Out:
# [3 4] [7 2]

# %%
a + b
# Out:
# array([10,  6])

# %%
a - b
# Out:
# array([-4,  2])

# %%
a * b
# Out:
# array([21,  8])

# %%
np.multiply(a,b)
# Out:
# array([21,  8])

# %%
print(a)
# Out:
# [3 4]

# %%
np.dot(2, a)
# Out:
# array([6, 8])

# %%
np.dot(5,4)
# Out:
# np.int64(20)

# %%
np.dot(a,b)
# Out:
# np.int64(29)

# %%
np.linalg.norm(a)
# Out:
# np.float64(5.0)

# %%
x = np.array([1,2,3])
np.linalg.norm(x)
# Out:
# np.float64(3.7416573867739413)

# %%
plt.quiver(3,4,angles='xy', scale_units='xy', scale=1)
plt.xlim(0,5)
plt.ylim(0,5)
plt.text(3,4, r'$\vec{u}$', fontsize=25, ha='right')
# Out:
# Text(3, 4, '$\\vec{u}$')

# %%
a = np.array([3,4])
b = np.array([7,2])
c = a + b

# %%
plt.quiver(a[0],a[1], angles='xy', scale_units='xy', scale=1)
plt.quiver(b[0],b[1], angles='xy', scale_units='xy', scale=1)
plt.quiver(c[0],c[1], angles='xy', scale_units='xy', scale=1, color='r')

plt.xlim(0,11)
plt.ylim(0,7)
# Out:
# (0.0, 7.0)

# %%
a = np.array([3,4])
b = np.array([7,2])
d = a - b

plt.quiver(a[0],a[1], angles='xy', scale_units='xy', scale=1)
plt.quiver(b[0],b[1], angles='xy', scale_units='xy', scale=1)
plt.quiver(d[0],d[1], angles='xy', scale_units='xy', scale=1, color='r')

plt.xlim(-5,9)
plt.ylim(-1,5)

plt.axvline(x=0,color='grey')
plt.axhline(y=0,color='grey')
plt.text(a[0],a[1],r'$\vec{A}$', size=20)
plt.text(b[0],b[1],r'$\vec{B}$', size=20)
plt.text(d[0],d[1],r'$\vec{B}$', size=20)
# Out:
# Text(-4, 2, '$\\vec{B}$')
